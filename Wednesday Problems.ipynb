# %%
import pandas as pd
import numpy as np
import seaborn as sns
% matplotlib inline

# %%
obesity_pd = pd.read_csv('CDC_Obesity_Data.csv')
obesity_pd
# Out:
#        YearStart  YearEnd LocationAbbr    LocationDesc  \
# 0           2011     2011           AL         Alabama
# 1           2011     2011           AL         Alabama
# 2           2011     2011           AL         Alabama
# 3           2011     2011           AL         Alabama
# 4           2011     2011           AL         Alabama
# 5           2011     2011           AL         Alabama
# 6           2011     2011           AL         Alabama
# 7           2011     2011           AL         Alabama
# 8           2011     2011           AL         Alabama
# 9           2011     2011           AL         Alabama
# 10          2011     2011           AL         Alabama
# 11          2011     2011           AL         Alabama
# 12          2011     2011           AL         Alabama
# 13          2011     2011           AL         Alabama
# 14          2011     2011           AL         Alabama
# 15          2011     2011           AL         Alabama
# ...

# %%
obesity_pd.columns
# Out:
# Index(['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'Datasource',
#        'Class', 'Topic', 'Question', 'Data_Value_Unit', 'Data_Value_Type',
#        'Data_Value', 'Data_Value_Alt', 'Data_Value_Footnote_Symbol',
#        'Data_Value_Footnote', 'Low_Confidence_Limit', 'High_Confidence_Limit ',
#        'Sample_Size', 'Total', 'Age(years)', 'Education', 'Gender', 'Income',
#        'Race/Ethnicity', 'GeoLocation', 'ClassID', 'TopicID', 'QuestionID',
#        'DataValueTypeID', 'LocationID', 'StratificationCategory1',
#        'Stratification1', 'StratificationCategoryId1', 'StratificationID1'],
#       dtype='object')

# %% [markdown]
# ### Problem 1:
# A is a set of values and X is an element of A. X is a random variable of a question that is an element in the question set (A).

# %% [markdown]
# ### Problem 2:
#
# B = "for all" of y, calculate "the sum" of all of the instances of y

# %% [markdown]
# ### Problem 3:
# https://seaborn.pydata.org/tutorial/distributions.html
#
# This follows a normal distribution with a big outlier at the value '0' because we assigned all the null values to zero

# %%
X = obesity_pd[obesity_pd['Question'] == 'Percent of adults aged 18 years and older who have obesity']
X_0 = X.fillna(0)
Y = X_0['Data_Value']

sns.distplot(Y)

# %% [markdown]
# ### Problem 4:
#
# https://seaborn.pydata.org/tutorial/distributions.html
#
# This follows a uniform distribution with vary little variance between the years which tells us that from 2011-2016 there hasn't been a change in obesity rates.

# %%
sns.jointplot('YearStart', 'Data_Value', X)
